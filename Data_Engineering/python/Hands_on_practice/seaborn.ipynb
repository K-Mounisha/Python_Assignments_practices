# %%
import seaborn as sns
import matplotlib.pyplot as plt
df=sns.load_dataset("tips")
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.scatterplot(data=df,x='total_bill',y='tip',color='g')
plt.show()

# %%
df.columns
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size'], dtype='str')

# %%
plt.figure(figsize=(25,15))
plt.subplot(1,2,1)
sns.scatterplot(data=df,x='total_bill',y='tip',hue='time')
plt.subplot(1,2,2)
sns.scatterplot(data=df,x='total_bill',y='tip',hue='size')
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.lineplot(data=df,x='total_bill',y='tip',color='g')
plt.show()

# %%
sns.barplot(data=df,x='day',y='total_bill')
plt.show()

# %%
df.shape
# Out:
# (244, 7)

# %%
sns.countplot(data=df,x='day')
plt.show()

# %%
sns.boxplot(data=df,x='day',y='total_bill')
plt.show()

# %%
sns.boxplot(data=df,x='day',y='total_bill',hue='sex')
plt.show()

# %%
sns.violinplot(data=df,x='day',y='total_bill')
plt.show()

# %%
sns.violinplot(data=df,x='day',y='total_bill',hue='sex')
plt.show()

# %%
sns.stripplot(data=df,x='day',y='total_bill')
plt.show()

# %%
df=df.sample(10000,replace=True)
df.shape
# Out:
# (10000, 7)

# %%
sns.histplot(data=df,x='total_bill',bins=15)
plt.show()

# %%
sns.rugplot(data=df,x='total_bill')
plt.show()

# %%
sns.regplot(data=df,x='total_bill',y='tip')
plt.show()

# %%
sns.jointplot(data=df,x='total_bill',y='tip',kind='scatter')
plt.show()

# %%
sns.jointplot(data=df,x='total_bill',y='tip')
plt.show()
