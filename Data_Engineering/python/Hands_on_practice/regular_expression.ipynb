# %%
import re

# %%
import re

pattern = "hello"
text = "hello world"

result = re.search(pattern, text)

if result:
    print("Match found")
# Out:
# Match found

# %%
pattern="reddy"
text="Mounisha Reddy"
result=re.search(pattern,text)
if result:
  print("Match found")
else:
  print("Match not found")
# Out:
# Match not found

# %%
re.match("cat","cat is cute")
#re.match("cat","my cat")
# Out:
# <re.Match object; span=(0, 3), match='cat'>

# %%
text="Contact me at test123@gmail.com"
emails=re.findall(r"\w+@\w+\.\w+",text)
print(emails)
# Out:
# ['test123@gmail.com']

# %%
phone="8555833685"
if re.fullmatch(r"\d{10}",phone):
  print("Valid number")
else:
  print("Ivalid number")
# Out:
# Valid number

# %%
text="My number is 9878 and code is 123"
re.findall(r"\d",text)
# Out:
# ['9', '8', '7', '8', '1', '2', '3']

# %%
text="My number is 9878 and code is 123"
re.findall(r"\w",text)
# Out:
# ['M',
#  'y',
#  'n',
#  'u',
#  'm',
#  'b',
#  'e',
#  'r',
#  'i',
#  's',
#  '9',
#  '8',
#  '7',
#  '8',
#  'a',
#  'n',
#  'd',
#  'c',
#  'o',
#  'd',
#  'e',
#  'i',
#  's',
#  '1',
#  '2',
#  '3']

# %%
text="My number is 9878 and code is 123"
re.findall(r"\w\s\w",text)
# Out:
# ['y n', 'r i', 's 9', '8 a', 'd c', 'e i', 's 1']

# %%
text="My number is 9878 and code is 123"
re.findall(r"\w+",text)
# Out:
# ['My', 'number', 'is', '9878', 'and', 'code', 'is', '123']

# %%
text = "Call 9876543210 or 9123456780"
re.findall(r"\d{10}",text)
# Out:
# ['9876543210', '9123456780']

# %%
text="I love data science"
re.sub(r"\s","*",text)
# Out:
# 'I*love*data*science'

# %%
text="car"
pattern=r"[car]"
matches=re.findall(pattern,text)
print("Matches:", matches)
# Out:
# Matches: ['c', 'a', 'r']

# %%
text="hello"
pattern=r"[a-n]"
matches=re.findall(pattern,text)
print("Matches:", matches)
# Out:
# Matches: ['h', 'e', 'l', 'l']

# %%
text="2025"
pattern=r"[0-4]"
matches=re.findall(pattern,text)
print("Matches:",matches)
# Out:
# Matches: ['2', '0', '2']

# %%
text="12, 67, 45"
pattern=r"[0-5][0-9]"
matches=re.findall(pattern,text)
print("Matches:", matches)
# Out:
# Matches: ['12', '45']

# %%
text="acb aab abb"
print(re.findall(r"a.b",text))
# Out:
# ['acb', 'aab', 'abb']

# %%
text="acb aab abb abc"
print(re.findall(r"a.c",text))
# Out:
# ['abc']

# %%
text="acb aab abb bac"
print(re.findall(r"b.c",text))
# Out:
# ['bac']

# %%
text="hlo world"
print(re.findall(r"^hlo",text))
# Out:
# ['hlo']

# %%
text="this is the end"
print(re.findall(r"end$",text))
# Out:
# ['end']

# %%
text="ab abb abbb a"
print(re.findall(r"ab*",text))
# Out:
# ['ab', 'abb', 'abbb', 'a']

# %%
text="ab abb abbb a"
print(re.findall(r"ab+",text))
# Out:
# ['ab', 'abb', 'abbb']

# %%
text="ab a abb abbb ba"
print(re.findall(r"ab?",text))
# Out:
# ['ab', 'a', 'ab', 'ab', 'a']

# %%
text="My number is 123"
print(re.findall(r"\d",text))
# Out:
# ['1', '2', '3']

# %%
text="Hello_123!"
print(re.findall(r"\w",text))
# Out:
# ['H', 'e', 'l', 'l', 'o', '_', '1', '2', '3']

# %%
text="Hi there is"
print(re.findall(r"\s",text))
# Out:
# [' ', ' ']

# %%
text="cat bat rat mat"
print(re.findall(r"[cb]at",text))
# Out:
# ['cat', 'bat']
