# %%
import numpy as np

# %%
data=np.random.randint(0,100,10)

# %%
data
# Out:
# array([54, 25, 74, 18, 12, 81, 59, 43, 90, 30])

# %%
data.min()
# Out:
# np.int64(12)

# %%
data.max()
# Out:
# np.int64(90)

# %%
range=data.max()-data.min()
range
# Out:
# np.int64(78)

# %%
data.mean()
# Out:
# np.float64(48.6)

# %%
np.median(data)
# Out:
# np.float64(48.5)

# %%
np.std(data)
# Out:
# np.float64(25.99307600111999)

# %%
np.var(data)
# Out:
# np.float64(675.64)

# %%
np.quantile(data,0.25)
# Out:
# np.float64(26.25)

# %%
import numpy as np

data = np.array([10, 20, 30, 40, 50])
print(np.quantile(data, 0.5))
# Out:
# 30.0

# %%
np.quantile(data,0.50),np.median(data)
# Out:
# (np.float64(30.0), np.float64(30.0))

# %%
np.quantile(data,0.75)
# Out:
# np.float64(40.0)

# %%
iqr=np.quantile(data,0.75)-np.quantile(data,0.25)
iqr
# Out:
# np.float64(20.0)

# %%
import numpy as np
np.random.seed(121)
data=np.random.randint(0,100,10)
data
# Out:
# array([66, 85,  8, 95, 65, 52, 83, 96, 46, 34])

# %%
data=np.random.randint(0,10,(3,10))

# %%
data
# Out:
# array([[4, 6, 3, 9, 4, 9, 8, 6, 7, 5],
#        [9, 9, 7, 3, 4, 8, 3, 4, 3, 4],
#        [2, 7, 7, 6, 4, 4, 9, 8, 0, 7]])

# %%
np.corrcoef(data)
# Out:
# array([[ 1.        , -0.29464184,  0.04777959],
#        [-0.29464184,  1.        , -0.13225824],
#        [ 0.04777959, -0.13225824,  1.        ]])

# %%
data.T
# Out:
# array([[4, 9, 2],
#        [6, 9, 7],
#        [3, 7, 7],
#        [9, 3, 6],
#        [4, 4, 4],
#        [9, 8, 4],
#        [8, 3, 9],
#        [6, 4, 8],
#        [7, 3, 0],
#        [5, 4, 7]])

# %%
import numpy as np
data=np.array([10,20,np.nan,40,50,np.nan,70])
print("Original data:", data)
# Out:
# Original data: [10. 20. nan 40. 50. nan 70.]

# %%
print("Null positions:", np.isnan(data))
# Out:
# Null positions: [False False  True False False  True False]

# %%
np.isnan(data).sum()
# Out:
# np.int64(2)

# %%
clean_data=data[~np.isnan(data)]
print("After removing nulls:", clean_data)
# Out:
# After removing nulls: [10. 20. 40. 50. 70.]

# %%
replace_zero=np.nan_to_num(data,nan=20)
print("Replace nan with 0:", replace_zero)
# Out:
# Replace nan with 0: [10. 20. 20. 40. 50. 20. 70.]

# %%
np.nanmean(data)
# Out:
# np.float64(38.0)

# %%
data.mean()
# Out:
# np.float64(nan)

# %%
np.nanmedian(data)
# Out:
# np.float64(40.0)

# %%
np.where(np.isnan(data),np.nanmedian(data),data)
# Out:
# array([10., 20., 40., 40., 50., 40., 70.])

# %%
import numpy as np
data=np.array([10,20,np.nan,40,50,np.nan,70])
print("Original data:", data)
print("Null Positions:", np.isnan(data))
print("Total Null Values:", np.isnan(data).sum())
lean_data = data[~np.isnan(data)]
print("After Removing Nulls:", clean_data)
# Out:
# Original data: [10. 20. nan 40. 50. nan 70.]
# Null Positions: [False False  True False False  True False]
# Total Null Values: 2
# After Removing Nulls: [10. 20. 40. 50. 70.]

# %%
print(data)
# Out:
# [10. 20. nan 40. 50. nan 70.]

# %%
print(np.isnan(data))
# Out:
# [False False  True False False  True False]

# %%
print(np.isnan(data).sum())
# Out:
# 2

# %%
clean_data=data[~np.isnan(data)]
clean_data
# Out:
# array([10., 20., 40., 50., 70.])

# %%
replace_zero=np.nan_to_num(data,nan=0)
replace_zero
# Out:
# array([10., 20.,  0., 40., 50.,  0., 70.])
