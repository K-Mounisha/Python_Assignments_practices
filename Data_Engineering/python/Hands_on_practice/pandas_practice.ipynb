# %%
import numpy as np
import pandas as pd

# %%
s=pd.Series([1,2,3,4])
print(s)
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# dtype: int64

# %%
df=pd.Series([1,2,3,'ram'])
print(df)
# Out:
# 0      1
# 1      2
# 2      3
# 3    ram
# dtype: object

# %%
df1=pd.Series(['sita','mounisha','maneesha'])
print(df1)
# Out:
# 0        sita
# 1    mounisha
# 2    maneesha
# dtype: object

# %%
data=pd.Series([1,2,3,4],index=['a','b','c','d'])
print(data)
# Out:
# a    1
# b    2
# c    3
# d    4
# dtype: int64

# %%
df=pd.Series([2,3,4,5,6.7,8.9,'ram','seetha',{'name':'seetha'}])
print(df)
# Out:
# 0                     2
# 1                     3
# 2                     4
# 3                     5
# 4                   6.7
# 5                   8.9
# 6                   ram
# 7                seetha
# 8    {'name': 'seetha'}
# dtype: object

# %%
names=pd.Series(['sitha','Chand','Ram'])
print(names[1])
print(names)
# Out:
# Chand
# 0    sitha
# 1    Chand
# 2      Ram
# dtype: object

# %%
s = pd.Series([10, 20, 30, 40], index=['a', 'b', 'c', 'd'])
print(s['b'])
# Out:
# 20

# %%
print(s['a'])
# Out:
# 10

# %%
s_list=pd.Series([34,25,6,7],index=['a','b','c','d'])
print(s_list)
# Out:
# a    34
# b    25
# c     6
# d     7
# dtype: int64

# %%
print(s_list['a'])
# Out:
# 34

# %%
print(f"2nd: {s_list['b']}")
# Out:
# 2nd: 25

# %%
data=pd.Series([30,45,49],index=['maths','science','chemistry'])
print(data)
# Out:
# maths        30
# science      45
# chemistry    49
# dtype: int64

# %%
dict={'a':10,'b':20,'c':30}
#p=pd.Series(dict,index=[0,1,2])
print(dict)
#print(p)
# Out:
# {'a': 10, 'b': 20, 'c': 30}

# %%
p=pd.Series(dict,index=[0,1,2])
print(p)
# Out:
# 0   NaN
# 1   NaN
# 2   NaN
# dtype: float64

# %%
dict={'a':10,'b':20,'c':30}
p=pd.Series(dict)
print(p)
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %%
data={
    'Name':['Ram','Sita','Chand','Lohit'],
    'Age':[25,30,28,31],
    'City':['Bangalore','Chennai','Hyderabad','Bangalore']
}
df=pd.DataFrame(data)
print(df)
# Out:
#     Name  Age       City
# 0    Ram   25  Bangalore
# 1   Sita   30    Chennai
# 2  Chand   28  Hyderabad
# 3  Lohit   31  Bangalore

# %%
data=pd.DataFrame({
    'Name':['ram','seeta'],
    'Age':[29,25]
})
print(data)
# Out:
#     Name  Age
# 0    ram   29
# 1  seeta   25

# %%
frames=pd.DataFrame({
    'Names':["Ram","Charan","Praveen"],
    'Age':[20,19,21],
    'Marks':[45,43,42]
})
print(frames)
# Out:
#      Names  Age  Marks
# 0      Ram   20     45
# 1   Charan   19     43
# 2  Praveen   21     42

# %%
df=pd.DataFrame({
    'Name':['Ravi','Raji','Chand'],
    'Marks':[34,50,50]
})
print(df)
# Out:
#     Name  Marks
# 0   Ravi     34
# 1   Raji     50
# 2  Chand     50

# %%
data=[
    {'Name':'Ravi','Age':25},
    {'Name':'Vikitha','Age':26}
]
data=pd.DataFrame(data,index=['a','b'])
print(data)
# Out:
#       Name  Age
# a     Ravi   25
# b  Vikitha   26

# %%
data=[
    ['Praveen',34],
    ['Charan',25]
]
df=pd.DataFrame(data,columns=['Name','age'])
print(df)
# Out:
#       Name  age
# 0  Praveen   34
# 1   Charan   25

# %%
df=pd.DataFrame([['Ram',25],['Janaki',30]],index=['Husband','Wife'],columns=['Name','Relationship'])
print(df)
# Out:
#            Name  Relationship
# Husband     Ram            25
# Wife     Janaki            30

# %%
column=pd.DataFrame([['Rani',19,'Bamgalore'],['Raju',18,'Chennai'],['Ravi',20,'Bangalore'],['Ram',19,'Kerala']],columns=['Name','age','City'])
print(column)
# Out:
#    Name  age       City
# 0  Rani   19  Bamgalore
# 1  Raju   18    Chennai
# 2  Ravi   20  Bangalore
# 3   Ram   19     Kerala

# %%
arr=np.array([[2,3],[3,4]])
df=pd.DataFrame(arr,columns=['A','B'])
print(df)
# Out:
#    A  B
# 0  2  3
# 1  3  4

# %%
s1=pd.Series([1,6])
s2=pd.Series([3,8])
df=pd.DataFrame({"col1":s1,"col2":s2})
print(df)
# Out:
#    col1  col2
# 0     1     3
# 1     6     8

# %%
s1=pd.Series(["Raju","Rani","Navin","Lohit"])
s2=pd.Series([23,34,48,44,50])
s3=pd.Series(["Bangalore","Chennai","Bangalore","Hyderabad"])
data=pd.DataFrame({"Name":s1,"Age":s2,"City":s3})
print(data)
# Out:
#     Name  Age       City
# 0   Raju   23  Bangalore
# 1   Rani   34    Chennai
# 2  Navin   48  Bangalore
# 3  Lohit   44  Hyderabad
# 4    NaN   50        NaN

# %%
df=pd.DataFrame({
    "Name":["Ram","Chand"],
    "Age":[20,30]
})
print(df)
# Out:
#     Name  Age
# 0    Ram   20
# 1  Chand   30

# %%
df_csv=pd.read_csv('data.csv')
df_excel=pd.read_excel('data.excel')
df_json=pd.read_json('data.json')
df_html=pd.read_html('data.html')
df_sql=pd.read_sql("SELECT * FROM users",con=db_connection)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_9580/228405586.py in <cell line: 0>()
# ----> 1 df_csv=pd.read_csv('data.csv')
#       2 df_excel=pd.read_excel('data.excel')
#       3 df_json=pd.read_json('data.json')
#       4 df_html=pd.read_html('data.html')
#       5 df_sql=pd.read_sql("SELECT * FROM users",con=db_connection)
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1024     kwds.update(kwds_defaults)
#    1025
# -> 1026     return _read(filepath_or_buffer, kwds)
#    1027
#    1028
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/parsers/readers.py in _read(filepath_or_buffer, kwds)
#     618
#     619     # Create the parser.
# --> 620     parser = TextFileReader(filepath_or_buffer, **kwds)
#     621
#     622     if chunksize or iterator:
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/parsers/readers.py in __init__(self, f, engine, **kwds)
#    1618
#    1619         self.handles: IOHandles | None = None
# -> 1620         self._engine = self._make_engine(f, self.engine)
#    1621
#    1622     def close(self) -> None:
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/parsers/readers.py in _make_engine(self, f, engine)
#    1878                 if "b" not in mode:
#    1879                     mode += "b"
# -> 1880             self.handles = get_handle(
#    1881                 f,
#    1882                 mode,
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     871         if ioargs.encoding and "b" not in ioargs.mode:
#     872             # Encoding
# --> 873             handle = open(
#     874                 handle,
#     875                 ioargs.mode,
#
# FileNotFoundError: [Errno 2] No such file or directory: 'data.csv'

# %%
names=df['Name']
subset=df[['Name','Age']]

# %%
print(names)

# %%
df=pd.DataFrame({
    "Name":["Ram","Chand"],
    "Age":[20,30]
})
names=df['Name']
print(names)
subset=df[['Name','Age']]
print(subset)

# %%
df=pd.DataFrame({
    "Name":["Ram","Sita","Hari"],
    "Age":[25,30,22]
})
print(df)
print(f"\nFirst Row:{df.loc[0]}")
df.loc[1]

# %%
df=pd.DataFrame({
    "Name":["Ram","Sita","Hari"],
    "Age":[25,30,22]
})
print(df)
df.iloc[1,0]

# %%
df=pd.DataFrame({
    "Name":["Ram","Sita","Hari"],
    "Age":[25,30,22]
})
print(df)
df.iloc[1,1]

# %%
df.iloc[0:2,0:2]

# %%
adults=df[df['Age']>=18]

# %%
filtered_df=df[(df['Age']>25) & (df['City']=='Banglore')]

# %%
df=pd.DataFrame({
    "Name":["Raju","Rani","Navin","Lohit"],
    "Age":[23,34,48,44],
    "City":["Bangalore","Chennai","Bangalore","Hyderabad"]
})
print(df)

# %%
age=df[df['Age']>=25]
print(f"\nSimple filter:{age}")

# %%
cities=['Chennai','Bangalore','Kerala']
eu_users=df[df['City'].isin(cities)]
print(eu_users)

# %%
filtered_df=df[(df['Age']>25)&(df['City']=='Bangalore')]
print(filtered_df)

# %%
df.isna().sum()
df_clean=df.dropna()
df_clean=df.dropna(subset=['city'])

# %%
df_filled=df.fillna(0)
df_filled=df['City'].fillna(df['City'].mean())

# %%
s1=pd.Series(["Raju","Rani","Navin","Lohit"])
s2=pd.Series([23,34,48,44,50])
s3=pd.Series(['Bangalore',"Chennai",'Bangalore',"Hyderabad"])
data=pd.DataFrame({"Name":s1,"Age":s2,"City":s3})
print(data)
missing=data.isna().sum()
print(missing)

# %%
s1=pd.Series(['Raju','Rani','Navin','Lohit'])
s2=pd.Series([23,34,48,44,50])
s3=pd.Series(["Bangalore","Chennai","Bangalore","Hyderabad"])
data=pd.DataFrame({"Name":s1,"Age":s2,"City":s3})
print(data)
df_clean=data.dropna()
print(df_clean)

# %%
s1=pd.Series(["Raju","Rani","Navin","Lohit"])
s2=pd.Series([23,34,48,44,50])
s3=pd.Series(["Bengalore","Chennai","Bengalore","Hydrabad"])
data=pd.DataFrame({"Name":s1,"Age":s2,"City":s3})
print(data)
df_clean=data.dropna(subset=['City'])
df_clean

# %%
s1=pd.Series(['Raju','Rani','Navin','Lohit'])
s2=pd.Series([23,34,48,44,50])
s3=pd.Series(['Bangalore','Chennai','Bangalore','Hyderabad'])
data=pd.DataFrame({"Name":s1,"Age":s2,"City":s3})
print(data)

# %%
data_filled=data.fillna(0)
print(data_filled)

# %%
s1=pd.Series(["Raju","Rani","Navin","Lohit","Raju"])
s2=pd.Series([23,34,48,44])
s3=pd.Series(["Bengalore","Chennai","Bengalore","Hydrabad"])
data=pd.DataFrame({"Name":s1,"Age":s2,"City":s3})
print(data)

# %%
data_filled=data['Age'].fillna(data['Age'].mean())
print(data_filled)

# %%
data_filled=data['Age'].fillna(data['Age'].median())
print(data_filled)

# %%
s1=pd.Series(['Raju','Rani','Navin','Lohit','Raju'])
s2=pd.Series([23,34,48,44,23])
s3=pd.Series(['Bangalore','Chennai','Bangalore','Hyderabad','Bangalore'])
data=pd.DataFrame({"Name":s1,'Age':s2,"City":s3})
print(data)

# %%
duplicates=data.duplicated().sum()
print(duplicates)

# %%
s1=pd.Series(["Raju","Rani","Navin","Lohit","Raju"])
s2=pd.Series([23,34,48,44,23])
s3=pd.Series(["Bengalore","Chennai","Bengalore","Hydrabad","Bengalore"])
data=pd.DataFrame({"Name":s1,"Age":s2,"City":s3})
print(data)
removed=data.drop_duplicates()
print(removed)

# %%
df=pd.DataFrame({
    "Name":["Raju","Rani","Navin"],
    "Status":["Y","N","Y"]
})
print(f"Before replacing:{df}")
df['Status']=df["Status"].replace({'Y':'Yes','N':'No'})
print(f"After replacing:{df}")

# %%
s1=pd.Series(["Raju","Rani","Navin","Lohit","Raju"])
s2=pd.Series([23,34,48,44,23])
s3=pd.Series(['Bangalore','Chennai','Bangalore','Hyderabad','Bangalore'])
data=pd.DataFrame({"Name":s1,"Age":s2,"City":s3})
print(data)

# %%
data["Age_in_month"]=data["Age"]*12
data

# %%
s1=pd.Series(["Raju","Rani","Navin","Lohit","Raju"])
s2=pd.Series([23,34,48,44,23])
s3=pd.Series(["Bengalore","Chennai","Bengalore","Hydrabad","Bengalore"])
data=pd.DataFrame({"Name":s1,"Age":s2,"City":s3})
data["Age_In_Months"]=data["Age"]*12
data=data.drop("Age_In_Months",axis=1)
print(data)

# %%
s1=pd.Series(["Raju","Rani","Navin","Lohit","Raju"])
s2=pd.Series([23,34,48,44,23])
s3=pd.Series(["Bengalore","Chennai","Bengalore","Hydrabad","Bengalore"])
data=pd.DataFrame({"Name":s1,"Age":s2,"City":s3})
print(data)
data=data.rename(columns={"Name":'Full name'})
print(data)

# %%
data=pd.DataFrame({
    "Name":['Ram','Ravi','Praveen','Lohith','Mounisha','Pavan','Chanz'],
    "Age":[23,54,23,60,40,50,61],
    "City":['Bangalore','Chennai','Hyderabad','Bangalore','Hyderabad','Hyderabad','Bangalore']
})
data["Is_Senior"]=data["Age"].apply(lambda age: True if age>=60 else False)
print(data)
# Out:
#        Name  Age       City  Is_Senior
# 0       Ram   23  Bangalore      False
# 1      Ravi   54    Chennai      False
# 2   Praveen   23  Hyderabad      False
# 3    Lohith   60  Bangalore       True
# 4  Mounisha   40  Hyderabad      False
# 5     Pavan   50  Hyderabad      False
# 6     Chanz   61  Bangalore       True

# %%
df["Upper_Name"]=df["Name"].str.upper()
df["First_name"]=df["Name"].str.split(' ').str[0]

# %%
df=pd.DataFrame({
    "Name":["Ram",'Ravi','Praveen','Lohith','Monisha','pavan',"Chanz"]
})
df["Upper_Name"]=df["Name"].str.upper()
print(df)
# Out:
#       Name Upper_Name
# 0      Ram        RAM
# 1     Ravi       RAVI
# 2  Praveen    PRAVEEN
# 3   Lohith     LOHITH
# 4  Monisha    MONISHA
# 5    pavan      PAVAN
# 6    Chanz      CHANZ

# %%
df=pd.DataFrame({
    "Name":['Ram Raj','Ravi sharma','Praveen kumar','Lohith Das','Monisha Singh','Pavan Sai','Chanz Robert']
})
df["First_Name"]=df["Name"].str.split(' ').str[0]
print(df)
# Out:
#             Name First_Name
# 0        Ram Raj        Ram
# 1    Ravi sharma       Ravi
# 2  Praveen kumar    Praveen
# 3     Lohith Das     Lohith
# 4  Monisha Singh    Monisha
# 5      Pavan Sai      Pavan
# 6   Chanz Robert      Chanz

# %%
df=pd.DataFrame({
    "Name":['Ram Raj','Ravi sharma','Praveen kumar','Lohith Das','Monisha Singh','Pavan Sai','Chanz Robert']
})
df["Last_Name"]=df["Name"].str.split(' ').str[1]
print(df)
# Out:
#             Name Last_Name
# 0        Ram Raj       Raj
# 1    Ravi sharma    sharma
# 2  Praveen kumar     kumar
# 3     Lohith Das       Das
# 4  Monisha Singh     Singh
# 5      Pavan Sai       Sai
# 6   Chanz Robert    Robert

# %%
data=pd.DataFrame({
    "Name":['Ram','Ravi','Praveen','Lohith','Monisha','Pavan','Chanz'],
    "Age":[23,45,23,22,40,50,59],
    "City":['Bengalore','Chennai','Hyderabad','Bengalore','Hyderabad','Hyderabad','Bengalore']
})
mean_age=data.groupby("City")["Age"].mean()
print(mean_age)
# Out:
# City
# Bengalore    34.666667
# Chennai      45.000000
# Hyderabad    37.666667
# Name: Age, dtype: float64

# %%
summary=df.groupby("City")["Age"].agg(["mean","max","min","count"])

# %%
data=pd.DataFrame({
    "Name":['Ram','Ravi','Praveen','Lohith','Monisha','Pavan','Chanz'],
    "Age":[23,45,23,22,40,50,59],
    "City":['Bengalore','Chennai','Hyderabad','Bengalore','Hyderabad','Hyderabad','Bengalore']
})
multiple_agg=data.groupby("City")["Age"].agg(["mean","max","min","count"])
print(multiple_agg)
# Out:
#                 mean  max  min  count
# City
# Bengalore  34.666667   59   22      3
# Chennai    45.000000   45   45      1
# Hyderabad  37.666667   50   23      3

# %%
add_dict={
    "Age":"mean",
    "Salary":['sum','max']
}
complex_summary=df.groupby('City').agg(agg_dict)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_9580/646701251.py in <cell line: 0>()
#       3     "Salary":['sum','max']
#       4 }
# ----> 5 complex_summary=df.groupby('City').agg(agg_dict)
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/frame.py in groupby(self, by, axis, level, as_index, sort, group_keys, observed, dropna)
#    9181             raise TypeError("You have to supply one of 'by' and 'level'")
#    9182
# -> 9183         return DataFrameGroupBy(
#    9184             obj=self,
#    9185             keys=by,
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/groupby/groupby.py in __init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, observed, dropna)
#    1327
#    1328         if grouper is None:
# -> 1329             grouper, exclusions, obj = get_grouper(
#    1330                 obj,
#    1331                 keys,
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/groupby/grouper.py in get_grouper(obj, key, axis, level, sort, observed, validate, dropna)
#    1041                 in_axis, level, gpr = False, gpr, None
#    1042             else:
# -> 1043                 raise KeyError(gpr)
#    1044         elif isinstance(gpr, Grouper) and gpr.key is not None:
#    1045             # Add key to exclusions
#
# KeyError: 'City'

# %%
data=pd.DataFrame({
    "Name":['Ram','Ravi','Praveen','Lohith','Monisha','Pavan','Chanz'],
    "Age":[23,45,23,22,40,50,59],
    "City":['Bengalore','Chennai','Hyderabad','Bengalore','Hyderabad','Hyderabad','Bengalore'],
    "Salary":[200,300,400,200,400,500,1000]
})
agg_dict={
    "Age":'mean',
    "Salary":['sum','max','min']
}
complex_summary=data.groupby("City").agg(agg_dict)
print(complex_summary)
# Out:
#                  Age Salary
#                 mean    sum   max  min
# City
# Bengalore  34.666667   1400  1000  200
# Chennai    45.000000    300   300  300
# Hyderabad  37.666667   1300   500  400

# %%
pivot=pd.pivot_table(
    df,
    values='Salary',
    index='City',
    columns='Depatment',
    aggfunc=np.mean,
    fill_value=0
)

# %%
df=pd.DataFrame({
    "Name":["A","B","C","D","E","F"],
    "City":["Bangalore","Bangalore","Chennai","Chennai","Bangalore","Chennai"],
    "Department":["HR","IT","HR","IT","HR","IT"],
    "Salary":[30000,40000,350,45000,32000,48000]
})
print(df)
pivot=pd.pivot_table(
    df,
    values='Salary',
    index='City',
    columns='Department',
    aggfunc=np.mean,
    fill_value=0
)
pivot
# Out:
#   Name       City Department  Salary
# 0    A  Bangalore         HR   30000
# 1    B  Bangalore         IT   40000
# 2    C    Chennai         HR     350
# 3    D    Chennai         IT   45000
# 4    E  Bangalore         HR   32000
# 5    F    Chennai         IT   48000
# /tmp/ipykernel_9580/495749614.py:8: FutureWarning: The provided callable <function mean at 0x799f88735800> is currently using DataFrameGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   pivot=pd.pivot_table(
# Department       HR       IT
# City
# Bangalore   31000.0  40000.0
# Chennai       350.0  46500.0

# %%
df1=pd.DataFrame({
    'Name':['Ravi','Raju','Sukanya'],
    'Age':[12,13,12]
})
df2=pd.DataFrame({
    'Name':['Ram','Sharath','Isha'],
    'Age':[14,11,10]
})
vertical_combine=pd.concat([df1,df2],axis=0)
print(vertical_combine)
# Out:
#       Name  Age
# 0     Ravi   12
# 1     Raju   13
# 2  Sukanya   12
# 0      Ram   14
# 1  Sharath   11
# 2     Isha   10

# %%
df1=pd.DataFrame({
    'Name':['Ravi','Raju','sukanya'],
    'Age':[12,13,12]
})
df2=pd.DataFrame({
    'Name':['Ram','Shrath','Isha'],
    'Age':[14,11,10]
})
hori_combine=pd.concat([df1,df2],axis=1)
print(hori_combine)
# Out:
#       Name  Age    Name  Age
# 0     Ravi   12     Ram   14
# 1     Raju   13  Shrath   11
# 2  sukanya   12    Isha   10

# %%
user_df=pd.DataFrame({
    'user_id':[1,2,3],
    'Name':['Ravi','Pavan','Venkat']
})
order_df=pd.DataFrame({
    'user_id':[1,2,4],
    'Order':['Laptop','Mobile','Tablet']
})
merged_df=pd.merge(user_df,order_df,on='user_id',how='inner')
print(merged_df)
# Out:
#    user_id   Name   Order
# 0        1   Ravi  Laptop
# 1        2  Pavan  Mobile

# %%
user_df=pd.DataFrame({
    'id':[1,2,3],
    'Name':['Ravi','Pavan','Venkat']
})
order_df=pd.DataFrame({
    'user_id':[1,2,4],
    'order':['Laptop','Mobile','Tablet']
})
left_join=pd.merge(user_df,order_df,left_on='id',right_on='user_id',how='left')
print(left_join)
# Out:
#    id    Name  user_id   order
# 0   1    Ravi      1.0  Laptop
# 1   2   Pavan      2.0  Mobile
# 2   3  Venkat      NaN     NaN

# %%
user_df=pd.DataFrame({
    'id':[1,2,3],
    'Name':['Ravi','Pavan','Venkat']
})
order_df=pd.DataFrame({
    'user_id':[1,2,4],
    'order':['Laptop','Mobile','Tablet']
})
right_join=pd.merge(user_df,order_df,left_on='id',right_on='user_id',how='right')
print(right_join)
# Out:
#     id   Name  user_id   order
# 0  1.0   Ravi        1  Laptop
# 1  2.0  Pavan        2  Mobile
# 2  NaN    NaN        4  Tablet

# %%
user_df=pd.DataFrame({
    'id':[1,2,3],
    'Name':['Ravi','Pavan','Venkat']
})
print(user_df)
order_df=pd.DataFrame({
    'user_id':[1,2,4],
    'order':['Laptop','Mobile','Tablet']
})
print(order_df)
outer_join=pd.merge(user_df,order_df,left_on='id',right_on='user_id',how='outer')
print(outer_join)
# Out:
#    id    Name
# 0   1    Ravi
# 1   2   Pavan
# 2   3  Venkat
#    user_id   order
# 0        1  Laptop
# 1        2  Mobile
# 2        4  Tablet
#     id    Name  user_id   order
# 0  1.0    Ravi      1.0  Laptop
# 1  2.0   Pavan      2.0  Mobile
# 2  3.0  Venkat      NaN     NaN
# 3  NaN     NaN      4.0  Tablet

# %%
 df=pd.DataFrame({
     "Date_String":["2023-01-01","2023-01-12","2023-02-10","2023-02-20"],
     "Revenue":[100,200,150,250]
 })
 df['Date']=pd.to_datetime(df['Date_String'])
 df['Year']=df['Date'].dt.year
 df['Month']=df['Date'].dt.month
 df['DayOfWeek']=df['Date'].dt.day_name()
 df.set_index('Date',inplace=True)
 df.loc['2023-01']
 monthly_revenue=df['Revenue'].resample('ME').sum()
 print(monthly_revenue)
 print(df)
# Out:
# Date
# 2023-01-31    300
# 2023-02-28    400
# Freq: ME, Name: Revenue, dtype: int64
#            Date_String  Revenue  Year  Month DayOfWeek
# Date
# 2023-01-01  2023-01-01      100  2023      1    Sunday
# 2023-01-12  2023-01-12      200  2023      1  Thursday
# 2023-02-10  2023-02-10      150  2023      2    Friday
# 2023-02-20  2023-02-20      250  2023      2    Monday
