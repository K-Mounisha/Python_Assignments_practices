# %%
import pandas as pd

# %%
df=pd.read_csv("https://gist.githubusercontent.com/nnbphuong/38db511db14542f3ba9ef16e69d3814c/raw/Superstore.csv")

# %%
df.shape
# Out:
# (9994, 21)

# %%
df.head
# Out:
# <bound method NDFrame.head of       Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 0          1  CA-2017-152156  2017-11-08  2017-11-11    Second Class
# 1          2  CA-2017-152156  2017-11-08  2017-11-11    Second Class
# 2          3  CA-2017-138688  2017-06-12  2017-06-16    Second Class
# 3          4  US-2016-108966  2016-10-11  2016-10-18  Standard Class
# 4          5  US-2016-108966  2016-10-11  2016-10-18  Standard Class
# ...      ...             ...         ...         ...             ...
# 9989    9990  CA-2015-110422  2015-01-21  2015-01-23    Second Class
# 9990    9991  CA-2018-121258  2018-02-26  2018-03-03  Standard Class
# 9991    9992  CA-2018-121258  2018-02-26  2018-03-03  Standard Class
# 9992    9993  CA-2018-121258  2018-02-26  2018-03-03  Standard Class
# 9993    9994  CA-2018-119914  2018-05-04  2018-05-09    Second Class
#
#      Customer ID     Customer Name    Segment        Country             City  \
# 0       CG-12520       Claire Gute   Consumer  United States        Henderson
# 1       CG-12520       Claire Gute   Consumer  United States        Henderson
# 2       DV-13045   Darrin Van Huff  Corporate  United States      Los Angeles
# 3       SO-20335    Sean O'Donnell   Consumer  United States  Fort Lauderdale
# 4       SO-20335    Sean O'Donnell   Consumer  United States  Fort Lauderdale
# ...          ...               ...        ...            ...              ...
# 9989    TB-21400  Tom Boeckenhauer   Consumer  United States            Miami
# 9990    DB-13060       Dave Brooks   Consumer  United States       Costa Mesa
# 9991    DB-13060       Dave Brooks   Consumer  United States       Costa Mesa
# 9992    DB-13060       Dave Brooks   Consumer  United States       Costa Mesa
# 9993    CC-12220      Chris Cortes   Consumer  United States      Westminster
#
#       ... Postal Code  Region       Product ID         Category Sub-Category  \
# 0     ...     42420.0   South  FUR-BO-10001798        Furniture    Bookcases
# 1     ...     42420.0   South  FUR-CH-10000454        Furniture       Chairs
# 2     ...     90036.0    West  OFF-LA-10000240  Office Supplies       Labels
# 3     ...     33311.0   South  FUR-TA-10000577        Furniture       Tables
# 4     ...     33311.0   South  OFF-ST-10000760  Office Supplies      Storage
# ...   ...         ...     ...              ...              ...          ...
# 9989  ...     33180.0   South  FUR-FU-10001889        Furniture  Furnishings
# 9990  ...     92627.0    West  FUR-FU-10000747        Furniture  Furnishings
# 9991  ...     92627.0    West  TEC-PH-10003645       Technology       Phones
# 9992  ...     92627.0    West  OFF-PA-10004041  Office Supplies        Paper
# 9993  ...     92683.0    West  OFF-AP-10002684  Office Supplies   Appliances
#
#                                            Product Name     Sales  Quantity  \
# 0                     Bush Somerset Collection Bookcase  261.9600         2
# 1     Hon Deluxe Fabric Upholstered Stacking Chairs,...  731.9400         3
# 2     Self-Adhesive Address Labels for Typewriters b...   14.6200         2
# 3         Bretford CR4500 Series Slim Rectangular Table  957.5775         5
# 4                        Eldon Fold 'N Roll Cart System   22.3680         2
# ...                                                 ...       ...       ...
# 9989                             Ultra Door Pull Handle   25.2480         3
# 9990  Tenex B1-RE Series Chair Mats for Low Pile Car...   91.9600         2
# 9991                              Aastra 57i VoIP phone  258.5760         2
# 9992  It's Hot Message Books with Stickers, 2 3/4" x 5"   29.6000         4
# 9993  Acco 7-Outlet Masterpiece Power Center, Wihtou...  243.1600         2
#
#       Discount    Profit
# 0         0.00   41.9136
# 1         0.00  219.5820
# 2         0.00    6.8714
# 3         0.45 -383.0310
# 4         0.20    2.5164
# ...        ...       ...
# 9989      0.20    4.1028
# 9990      0.00   15.6332
# 9991      0.20   19.3932
# 9992      0.00   13.3200
# 9993      0.00   72.9480
#
# [9994 rows x 21 columns]>

# %%
df.tail
# Out:
# <bound method NDFrame.tail of       Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 0          1  CA-2017-152156  2017-11-08  2017-11-11    Second Class
# 1          2  CA-2017-152156  2017-11-08  2017-11-11    Second Class
# 2          3  CA-2017-138688  2017-06-12  2017-06-16    Second Class
# 3          4  US-2016-108966  2016-10-11  2016-10-18  Standard Class
# 4          5  US-2016-108966  2016-10-11  2016-10-18  Standard Class
# ...      ...             ...         ...         ...             ...
# 9989    9990  CA-2015-110422  2015-01-21  2015-01-23    Second Class
# 9990    9991  CA-2018-121258  2018-02-26  2018-03-03  Standard Class
# 9991    9992  CA-2018-121258  2018-02-26  2018-03-03  Standard Class
# 9992    9993  CA-2018-121258  2018-02-26  2018-03-03  Standard Class
# 9993    9994  CA-2018-119914  2018-05-04  2018-05-09    Second Class
#
#      Customer ID     Customer Name    Segment        Country             City  \
# 0       CG-12520       Claire Gute   Consumer  United States        Henderson
# 1       CG-12520       Claire Gute   Consumer  United States        Henderson
# 2       DV-13045   Darrin Van Huff  Corporate  United States      Los Angeles
# 3       SO-20335    Sean O'Donnell   Consumer  United States  Fort Lauderdale
# 4       SO-20335    Sean O'Donnell   Consumer  United States  Fort Lauderdale
# ...          ...               ...        ...            ...              ...
# 9989    TB-21400  Tom Boeckenhauer   Consumer  United States            Miami
# 9990    DB-13060       Dave Brooks   Consumer  United States       Costa Mesa
# 9991    DB-13060       Dave Brooks   Consumer  United States       Costa Mesa
# 9992    DB-13060       Dave Brooks   Consumer  United States       Costa Mesa
# 9993    CC-12220      Chris Cortes   Consumer  United States      Westminster
#
#       ... Postal Code  Region       Product ID         Category Sub-Category  \
# 0     ...     42420.0   South  FUR-BO-10001798        Furniture    Bookcases
# 1     ...     42420.0   South  FUR-CH-10000454        Furniture       Chairs
# 2     ...     90036.0    West  OFF-LA-10000240  Office Supplies       Labels
# 3     ...     33311.0   South  FUR-TA-10000577        Furniture       Tables
# 4     ...     33311.0   South  OFF-ST-10000760  Office Supplies      Storage
# ...   ...         ...     ...              ...              ...          ...
# 9989  ...     33180.0   South  FUR-FU-10001889        Furniture  Furnishings
# 9990  ...     92627.0    West  FUR-FU-10000747        Furniture  Furnishings
# 9991  ...     92627.0    West  TEC-PH-10003645       Technology       Phones
# 9992  ...     92627.0    West  OFF-PA-10004041  Office Supplies        Paper
# 9993  ...     92683.0    West  OFF-AP-10002684  Office Supplies   Appliances
#
#                                            Product Name     Sales  Quantity  \
# 0                     Bush Somerset Collection Bookcase  261.9600         2
# 1     Hon Deluxe Fabric Upholstered Stacking Chairs,...  731.9400         3
# 2     Self-Adhesive Address Labels for Typewriters b...   14.6200         2
# 3         Bretford CR4500 Series Slim Rectangular Table  957.5775         5
# 4                        Eldon Fold 'N Roll Cart System   22.3680         2
# ...                                                 ...       ...       ...
# 9989                             Ultra Door Pull Handle   25.2480         3
# 9990  Tenex B1-RE Series Chair Mats for Low Pile Car...   91.9600         2
# 9991                              Aastra 57i VoIP phone  258.5760         2
# 9992  It's Hot Message Books with Stickers, 2 3/4" x 5"   29.6000         4
# 9993  Acco 7-Outlet Masterpiece Power Center, Wihtou...  243.1600         2
#
#       Discount    Profit
# 0         0.00   41.9136
# 1         0.00  219.5820
# 2         0.00    6.8714
# 3         0.45 -383.0310
# 4         0.20    2.5164
# ...        ...       ...
# 9989      0.20    4.1028
# 9990      0.00   15.6332
# 9991      0.20   19.3932
# 9992      0.00   13.3200
# 9993      0.00   72.9480
#
# [9994 rows x 21 columns]>

# %%
df['Sales'].sum()
# Out:
# np.float64(2297200.8603)

# %%
df['Sales'].mean()
# Out:
# np.float64(229.85800083049827)

# %%
df['Sales'].median()
# Out:
# np.float64(54.489999999999995)

# %%
df['Quantity'].mode()
# Out:
# 0    3
# Name: Quantity, dtype: int64

# %%
df['Sales'].min()
# Out:
# np.float64(0.444)

# %%
df['Sales'].max()
# Out:
# np.float64(22638.48)

# %%
df['Sales'].count()
# Out:
# np.int64(9994)

# %%
df['Sales'].std()
# Out:
# np.float64(623.2451005086808)

# %%
df['Sales'].var()
# Out:
# np.float64(388434.45530807565)

# %%
df['Sales'].product()
# Out:
# c:\Users\Administrator\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\numpy\_core\_methods.py:53: RuntimeWarning: overflow encountered in reduce
#   return umr_prod(a, axis, dtype, out, keepdims, initial, where)
# np.float64(inf)

# %%
df['Sales'].cumsum()
# Out:
# 0       2.619600e+02
# 1       9.939000e+02
# 2       1.008520e+03
# 3       1.966098e+03
# 4       1.988466e+03
#             ...
# 9989    2.296578e+06
# 9990    2.296670e+06
# 9991    2.296928e+06
# 9992    2.296958e+06
# 9993    2.297201e+06
# Name: Sales, Length: 9994, dtype: float64

# %%
df['Sales'].cummax()
# Out:
# 0         261.9600
# 1         731.9400
# 2         731.9400
# 3         957.5775
# 4         957.5775
#            ...
# 9989    22638.4800
# 9990    22638.4800
# 9991    22638.4800
# 9992    22638.4800
# 9993    22638.4800
# Name: Sales, Length: 9994, dtype: float64

# %%
df['Sales'].cummin()
# Out:
# 0       261.960
# 1       261.960
# 2        14.620
# 3        14.620
# 4        14.620
#          ...
# 9989      0.444
# 9990      0.444
# 9991      0.444
# 9992      0.444
# 9993      0.444
# Name: Sales, Length: 9994, dtype: float64

# %%
df['Sales'].cumprod()
# Out:
# c:\Users\Administrator\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\numpy\_core\fromnumeric.py:54: RuntimeWarning: overflow encountered in accumulate
#   return bound(*args, **kwds)
# 0       2.619600e+02
# 1       1.917390e+05
# 2       2.803224e+06
# 3       2.684304e+09
# 4       6.004252e+10
#             ...
# 9989             inf
# 9990             inf
# 9991             inf
# 9992             inf
# 9993             inf
# Name: Sales, Length: 9994, dtype: float64

# %%
import pandas as pd
import numpy as np
data = {
    'Month': ['Jan','Feb','Mar','Apr','May','Jun'],
    'Sales': [1000, 1500, 1200, 1800, 2000, 1700],
    'Profit': [200, 300, 250, 400, 500, 350],
    'Expenses': [800, 1200, 950, 1400, 1500, 1350]
}

# %%
df=pd.DataFrame(data)

# %%
df
# Out:
#   Month  Sales  Profit  Expenses
# 0   Jan   1000     200       800
# 1   Feb   1500     300      1200
# 2   Mar   1200     250       950
# 3   Apr   1800     400      1400
# 4   May   2000     500      1500
# 5   Jun   1700     350      1350

# %%
df.set_index('Month',inplace=True)

# %%
df
# Out:
#        Sales  Profit  Expenses
# Month
# Jan     1000     200       800
# Feb     1500     300      1200
# Mar     1200     250       950
# Apr     1800     400      1400
# May     2000     500      1500
# Jun     1700     350      1350

# %%
import matplotlib.pyplot as plt

# %%
plt.plot([1,2,3,4],[10,20,30,40])
plt.show()

# %%
df['Sales'].plot(title="Line Plot - Sales Trend")
plt.show()

# %%
df[['Sales','Profit']].plot(title="Multiple Line Plot")
# Out:
# <Axes: title={'center': 'Multiple Line Plot'}, xlabel='Month'>

# %%
df['Sales'].plot(kind='bar',title="Bar Plot-Sales")
# Out:
# <Axes: title={'center': 'Bar Plot-Sales'}, xlabel='Month'>

# %%
df[['Sales','Profit']].plot(kind='bar',stacked=True,title='Stacked Bar Plot')
# Out:
# <Axes: title={'center': 'Stacked Bar Plot'}, xlabel='Month'>

# %%
df['Sales'].plot(kind='barh',title="Horizontal Bar Plot")
# Out:
# <Axes: title={'center': 'Horizontal Bar Plot'}, ylabel='Month'>

# %%
df['Sales'].plot(kind='hist',bins=5,title="Histogram-Sales")
# Out:
# <Axes: title={'center': 'Histogram-Sales'}, ylabel='Frequency'>

# %%
df[['Sales','Profit']].plot(kind='box',title="Box plot")
# Out:
# <Axes: title={'center': 'Box plot'}>

# %%
df[['Sales','Profit']].plot(kind='area',title="Area Plot")
# Out:
# <Axes: title={'center': 'Area Plot'}, xlabel='Month'>

# %%
df['Sales'].plot(kind='pie',autopct='%1.1f%%',title="Pie Chart-Sales")
# Out:
# <Axes: title={'center': 'Pie Chart-Sales'}>

# %%
df['Sales'].plot(kind='pie', title="Pie Chart - Sales")
# Out:
# <Axes: title={'center': 'Pie Chart - Sales'}>

# %%
df.plot(kind='scatter',x='Sales',y='Profit',title="Scatter Plot")
# Out:
# <Axes: title={'center': 'Scatter Plot'}, xlabel='Sales', ylabel='Profit'>

# %%
df.shape
# Out:
# (6, 3)

# %%
df=pd.read_csv("https://gist.githubusercontent.com/nnbphuong/38db511db14542f3ba9ef16e69d3814c/raw/Superstore.csv")

# %%
df.shape
# Out:
# (9994, 21)

# %%
df.dtypes
# Out:
# Row ID             int64
# Order ID             str
# Order Date           str
# Ship Date            str
# Ship Mode            str
# Customer ID          str
# Customer Name        str
# Segment              str
# Country              str
# City                 str
# State                str
# Postal Code      float64
# Region               str
# Product ID           str
# Category             str
# Sub-Category         str
# Product Name         str
# Sales            float64
# Quantity           int64
# Discount         float64
# Profit           float64
# dtype: object

# %%
df.describe
# Out:
# <bound method NDFrame.describe of       Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 0          1  CA-2017-152156  2017-11-08  2017-11-11    Second Class
# 1          2  CA-2017-152156  2017-11-08  2017-11-11    Second Class
# 2          3  CA-2017-138688  2017-06-12  2017-06-16    Second Class
# 3          4  US-2016-108966  2016-10-11  2016-10-18  Standard Class
# 4          5  US-2016-108966  2016-10-11  2016-10-18  Standard Class
# ...      ...             ...         ...         ...             ...
# 9989    9990  CA-2015-110422  2015-01-21  2015-01-23    Second Class
# 9990    9991  CA-2018-121258  2018-02-26  2018-03-03  Standard Class
# 9991    9992  CA-2018-121258  2018-02-26  2018-03-03  Standard Class
# 9992    9993  CA-2018-121258  2018-02-26  2018-03-03  Standard Class
# 9993    9994  CA-2018-119914  2018-05-04  2018-05-09    Second Class
#
#      Customer ID     Customer Name    Segment        Country             City  \
# 0       CG-12520       Claire Gute   Consumer  United States        Henderson
# 1       CG-12520       Claire Gute   Consumer  United States        Henderson
# 2       DV-13045   Darrin Van Huff  Corporate  United States      Los Angeles
# 3       SO-20335    Sean O'Donnell   Consumer  United States  Fort Lauderdale
# 4       SO-20335    Sean O'Donnell   Consumer  United States  Fort Lauderdale
# ...          ...               ...        ...            ...              ...
# 9989    TB-21400  Tom Boeckenhauer   Consumer  United States            Miami
# 9990    DB-13060       Dave Brooks   Consumer  United States       Costa Mesa
# 9991    DB-13060       Dave Brooks   Consumer  United States       Costa Mesa
# 9992    DB-13060       Dave Brooks   Consumer  United States       Costa Mesa
# 9993    CC-12220      Chris Cortes   Consumer  United States      Westminster
#
#       ... Postal Code  Region       Product ID         Category Sub-Category  \
# 0     ...     42420.0   South  FUR-BO-10001798        Furniture    Bookcases
# 1     ...     42420.0   South  FUR-CH-10000454        Furniture       Chairs
# 2     ...     90036.0    West  OFF-LA-10000240  Office Supplies       Labels
# 3     ...     33311.0   South  FUR-TA-10000577        Furniture       Tables
# 4     ...     33311.0   South  OFF-ST-10000760  Office Supplies      Storage
# ...   ...         ...     ...              ...              ...          ...
# 9989  ...     33180.0   South  FUR-FU-10001889        Furniture  Furnishings
# 9990  ...     92627.0    West  FUR-FU-10000747        Furniture  Furnishings
# 9991  ...     92627.0    West  TEC-PH-10003645       Technology       Phones
# 9992  ...     92627.0    West  OFF-PA-10004041  Office Supplies        Paper
# 9993  ...     92683.0    West  OFF-AP-10002684  Office Supplies   Appliances
#
#                                            Product Name     Sales  Quantity  \
# 0                     Bush Somerset Collection Bookcase  261.9600         2
# 1     Hon Deluxe Fabric Upholstered Stacking Chairs,...  731.9400         3
# 2     Self-Adhesive Address Labels for Typewriters b...   14.6200         2
# 3         Bretford CR4500 Series Slim Rectangular Table  957.5775         5
# 4                        Eldon Fold 'N Roll Cart System   22.3680         2
# ...                                                 ...       ...       ...
# 9989                             Ultra Door Pull Handle   25.2480         3
# 9990  Tenex B1-RE Series Chair Mats for Low Pile Car...   91.9600         2
# 9991                              Aastra 57i VoIP phone  258.5760         2
# 9992  It's Hot Message Books with Stickers, 2 3/4" x 5"   29.6000         4
# 9993  Acco 7-Outlet Masterpiece Power Center, Wihtou...  243.1600         2
#
#       Discount    Profit
# 0         0.00   41.9136
# 1         0.00  219.5820
# 2         0.00    6.8714
# 3         0.45 -383.0310
# 4         0.20    2.5164
# ...        ...       ...
# 9989      0.20    4.1028
# 9990      0.00   15.6332
# 9991      0.20   19.3932
# 9992      0.00   13.3200
# 9993      0.00   72.9480
#
# [9994 rows x 21 columns]>

# %%
df.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Country', 'City', 'State',
#        'Postal Code', 'Region', 'Product ID', 'Category', 'Sub-Category',
#        'Product Name', 'Sales', 'Quantity', 'Discount', 'Profit'],
#       dtype='str')

# %%
df.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Country', 'City', 'State',
#        'Postal Code', 'Region', 'Product ID', 'Category', 'Sub-Category',
#        'Product Name', 'Sales', 'Quantity', 'Discount', 'Profit'],
#       dtype='str')

# %%
df[['Sales','Profit']].mean()
# Out:
# Sales     229.858001
# Profit     28.656896
# dtype: float64

# %%
df[['Sales','Profit']].sum()/df.shape[0]
# Out:
# Sales     229.858001
# Profit     28.656896
# dtype: float64

# %%
df['Customer Name'].str.lower()
# Out:
# 0            claire gute
# 1            claire gute
# 2        darrin van huff
# 3         sean o'donnell
# 4         sean o'donnell
#               ...
# 9989    tom boeckenhauer
# 9990         dave brooks
# 9991         dave brooks
# 9992         dave brooks
# 9993        chris cortes
# Name: Customer Name, Length: 9994, dtype: str

# %%
df['Customer Name'].str.upper()
# Out:
# 0            CLAIRE GUTE
# 1            CLAIRE GUTE
# 2        DARRIN VAN HUFF
# 3         SEAN O'DONNELL
# 4         SEAN O'DONNELL
#               ...
# 9989    TOM BOECKENHAUER
# 9990         DAVE BROOKS
# 9991         DAVE BROOKS
# 9992         DAVE BROOKS
# 9993        CHRIS CORTES
# Name: Customer Name, Length: 9994, dtype: str

# %%
df['Customer Name'].str.len()
# Out:
# 0       11
# 1       11
# 2       15
# 3       14
# 4       14
#         ..
# 9989    16
# 9990    11
# 9991    11
# 9992    11
# 9993    12
# Name: Customer Name, Length: 9994, dtype: int64

# %%
df['Customer Name'].str.strip()
# Out:
# 0            Claire Gute
# 1            Claire Gute
# 2        Darrin Van Huff
# 3         Sean O'Donnell
# 4         Sean O'Donnell
#               ...
# 9989    Tom Boeckenhauer
# 9990         Dave Brooks
# 9991         Dave Brooks
# 9992         Dave Brooks
# 9993        Chris Cortes
# Name: Customer Name, Length: 9994, dtype: str

# %%
df['City'].str.replace('New York','NY')
# Out:
# 0             Henderson
# 1             Henderson
# 2           Los Angeles
# 3       Fort Lauderdale
# 4       Fort Lauderdale
#              ...
# 9989              Miami
# 9990         Costa Mesa
# 9991         Costa Mesa
# 9992         Costa Mesa
# 9993        Westminster
# Name: City, Length: 9994, dtype: str

# %%
df[df['Product Name'].str.contains('Chair')]
# Out:
#       Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 1          2  CA-2017-152156  2017-11-08  2017-11-11    Second Class
# 23        24  US-2018-156909  2018-07-16  2018-07-18    Second Class
# 39        40  CA-2016-117415  2016-12-27  2016-12-31  Standard Class
# 52        53  CA-2016-115742  2016-04-18  2016-04-22  Standard Class
# 57        58  CA-2017-111682  2017-06-17  2017-06-18     First Class
# ...      ...             ...         ...         ...             ...
# 9908    9909  US-2016-129007  2016-09-13  2016-09-15     First Class
# 9912    9913  CA-2016-132388  2016-10-10  2016-10-12     First Class
# 9919    9920  CA-2017-149272  2017-03-15  2017-03-19  Standard Class
# 9947    9948  CA-2018-121559  2018-06-01  2018-06-03    Second Class
# 9990    9991  CA-2018-121258  2018-02-26  2018-03-03  Standard Class
#
#      Customer ID      Customer Name      Segment        Country  \
# 1       CG-12520        Claire Gute     Consumer  United States
# 23      SF-20065    Sandra Flanagan     Consumer  United States
# 39      SN-20710       Steve Nguyen  Home Office  United States
# 52      DP-13000      Darren Powers     Consumer  United States
# 57      TB-21055    Ted Butterfield     Consumer  United States
# ...          ...                ...          ...            ...
# 9908    KD-16615           Ken Dana    Corporate  United States
# 9912    KN-16390  Katherine Nockton    Corporate  United States
# 9919    MY-18295    Muhammed Yedwab    Corporate  United States
# 9947    HW-14935    Helen Wasserman    Corporate  United States
# 9990    DB-13060        Dave Brooks     Consumer  United States
#
#                City  ... Postal Code   Region       Product ID   Category  \
# 1         Henderson  ...     42420.0    South  FUR-CH-10000454  Furniture
# 23     Philadelphia  ...     19140.0     East  FUR-CH-10002774  Furniture
# 39          Houston  ...     77041.0  Central  FUR-CH-10004218  Furniture
# 52       New Albany  ...     47150.0  Central  FUR-CH-10003061  Furniture
# 57             Troy  ...     12180.0     East  FUR-CH-10003968  Furniture
# ...             ...  ...         ...      ...              ...        ...
# 9908        Anaheim  ...     92804.0     West  FUR-FU-10002379  Furniture
# 9912  Santa Barbara  ...     93101.0     West  FUR-CH-10001714  Furniture
# 9919          Bryan  ...     77803.0  Central  FUR-CH-10000863  Furniture
# 9947   Indianapolis  ...     46203.0  Central  FUR-CH-10003746  Furniture
# 9990     Costa Mesa  ...     92627.0     West  FUR-FU-10000747  Furniture
#
#      Sub-Category                                       Product Name  \
# 1          Chairs  Hon Deluxe Fabric Upholstered Stacking Chairs,...
# 23         Chairs                 Global Deluxe Stacking Chair, Gray
# 39         Chairs           Global Fabric Manager's Chair, Dark Gray
# 52         Chairs                   Global Leather Task Chair, Black
# 57         Chairs                           Novimex Turbo Task Chair
# ...           ...                                                ...
# 9908  Furnishings   Eldon Econocleat Chair Mats for Low Pile Carpets
# 9912       Chairs     Global Leather & Oak Executive Chair, Burgundy
# 9919       Chairs                   Novimex Swivel Fabric Task Chair
# 9947       Chairs  Hon 4070 Series Pagoda Round Back Stacking Chairs
# 9990  Furnishings  Tenex B1-RE Series Chair Mats for Low Pile Car...
#
#          Sales  Quantity  Discount    Profit
# 1      731.940         3       0.0  219.5820
# 23      71.372         2       0.3   -1.0196
# 39     212.058         3       0.3  -15.1470
# 52      89.990         1       0.0   17.0981
# 57     319.410         5       0.1    7.0980
# ...        ...       ...       ...       ...
# 9908   207.350         5       0.0   24.8820
# 9912   362.136         3       0.2  -54.3204
# 9919   528.430         5       0.3 -143.4310
# 9947  1925.880         6       0.0  539.2464
# 9990    91.960         2       0.0   15.6332
#
# [677 rows x 21 columns]

# %%
df[df['Customer Name'].str.startswith('A')]
# Out:
#       Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 12        13  CA-2018-114412  2018-04-15  2018-04-20  Standard Class
# 17        18  CA-2015-167164  2015-05-13  2015-05-15    Second Class
# 124      125  US-2015-152030  2015-12-26  2015-12-28    Second Class
# 187      188  CA-2017-157000  2017-07-16  2017-07-22  Standard Class
# 188      189  CA-2017-157000  2017-07-16  2017-07-22  Standard Class
# ...      ...             ...         ...         ...             ...
# 9975    9976  US-2017-103674  2017-12-06  2017-12-10  Standard Class
# 9976    9977  US-2017-103674  2017-12-06  2017-12-10  Standard Class
# 9977    9978  US-2017-103674  2017-12-06  2017-12-10  Standard Class
# 9978    9979  US-2017-103674  2017-12-06  2017-12-10  Standard Class
# 9979    9980  US-2017-103674  2017-12-06  2017-12-10  Standard Class
#
#      Customer ID    Customer Name      Segment        Country           City  \
# 12      AA-10480     Andrew Allen     Consumer  United States        Concord
# 17      AG-10270  Alejandro Grove     Consumer  United States    West Jordan
# 124     AD-10180   Alan Dominguez  Home Office  United States        Houston
# 187     AM-10360   Alice McCarthy    Corporate  United States  Grand Prairie
# 188     AM-10360   Alice McCarthy    Corporate  United States  Grand Prairie
# ...          ...              ...          ...            ...            ...
# 9975    AP-10720       Anne Pryor  Home Office  United States    Los Angeles
# 9976    AP-10720       Anne Pryor  Home Office  United States    Los Angeles
# 9977    AP-10720       Anne Pryor  Home Office  United States    Los Angeles
# 9978    AP-10720       Anne Pryor  Home Office  United States    Los Angeles
# 9979    AP-10720       Anne Pryor  Home Office  United States    Los Angeles
#
#       ... Postal Code   Region       Product ID         Category Sub-Category  \
# 12    ...     28027.0    South  OFF-PA-10002365  Office Supplies        Paper
# 17    ...     84084.0     West  OFF-ST-10000107  Office Supplies      Storage
# 124   ...     77041.0  Central  FUR-CH-10004063        Furniture       Chairs
# 187   ...     75051.0  Central  OFF-ST-10001328  Office Supplies      Storage
# 188   ...     75051.0  Central  OFF-PA-10001950  Office Supplies        Paper
# ...   ...         ...      ...              ...              ...          ...
# 9975  ...     90032.0     West  OFF-PA-10000743  Office Supplies        Paper
# 9976  ...     90032.0     West  TEC-PH-10002496       Technology       Phones
# 9977  ...     90032.0     West  OFF-FA-10003467  Office Supplies    Fasteners
# 9978  ...     90032.0     West  OFF-BI-10003727  Office Supplies      Binders
# 9979  ...     90032.0     West  OFF-BI-10002026  Office Supplies      Binders
#
#                                            Product Name    Sales  Quantity  \
# 12                                           Xerox 1967   15.552         3
# 17                           Fellowes Super Stor/Drawer   55.500         2
# 124             Global Deluxe High-Back Manager's Chair  600.558         3
# 187           Personal Filing Tote with Lid, Black/Gray   37.224         3
# 188   Southworth 25% Cotton Antique Laid Paper & Env...   20.016         3
# ...                                                 ...      ...       ...
# 9975                                         Xerox 1977   13.360         2
# 9976                                       Cisco SPA301  249.584         2
# 9977           Alliance Big Bands Rubber Bands, 12/Pack   13.860         7
# 9978  Avery Durable Slant Ring Binders With Label Ho...   13.376         4
# 9979                  Ibico Recycled Linen-Style Covers  437.472        14
#
#       Discount    Profit
# 12         0.2    5.4432
# 17         0.0    9.9900
# 124        0.3   -8.5794
# 187        0.2    3.7224
# 188        0.2    6.2550
# ...        ...       ...
# 9975       0.0    6.4128
# 9976       0.2   31.1980
# 9977       0.0    0.0000
# 9978       0.2    4.6816
# 9979       0.2  153.1152
#
# [784 rows x 21 columns]
