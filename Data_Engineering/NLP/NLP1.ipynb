# %%
import re

# %%
text="This class is about DataScience"
re.search("class",text)
# Out:
# <re.Match object; span=(5, 10), match='class'>

# %%
re.search("is",text)
# Out:
# <re.Match object; span=(2, 4), match='is'>

# %%
re.search("This",text)
# Out:
# <re.Match object; span=(0, 4), match='This'>

# %%
text2="This class is about DataScience. there are 30 people in the class"

# %%
re.match("This",text2)
# Out:
# <re.Match object; span=(0, 4), match='This'>

# %%
text3="the cat sat on the mat and saw another cat"
re.findall("cat",text3)
# Out:
# ['cat', 'cat']

# %%
re.findall("the",text3)
# Out:
# ['the', 'the', 'the']

# %%
text4="I completed my graduation in 2025."
re.findall("[0-9]",text4)
# Out:
# ['2', '0', '2', '5']

# %%
text5="I rollno is 214m1a0547 and completed in 2025 with 76.6"
re.findall("[0-9]",text5)
# Out:
# ['2', '1', '4', '1', '0', '5', '4', '7', '2', '0', '2', '5', '7', '6', '6']

# %%
re.findall("[aeiou]",text4)
# Out:
# ['o', 'e', 'e', 'a', 'u', 'a', 'i', 'o', 'i']

# %%
text4
# Out:
# 'I completed my graduation in 2025.'

# %%
re.sub(r"\d+","the year of 2025",text4)
# Out:
# 'I completed my graduation in the year of 2025.'

# %%
text6="My mobile number is 9000083385"
re.sub(r"\d{10}","****",text6)
# Out:
# 'My mobile number is ****'

# %%
re.sub(r"\d{10}","**********",text6)
# Out:
# 'My mobile number is **********'

# %%
re.sub(r"\d{9}","****",text6)
# Out:
# 'My mobile number is ****5'

# %%
.^$*+?{[(

# %%
from typing_extensions import Optional
. any character except new line_magic
^ startswith
$endswith
*0 or more
+1 or more
# ?Optional
{Repitition}
[character set]
(grouping)

# %%
string1="This is my mobile number 9000033685 and pan number:LITPK7695D."
re.findall(r"[A-Z]{5}[0-9]{4}[A-Z]",string1)
# Out:
# ['LITPK7695D']

# %%
re.findall(r"[0-9]{10}",string1)
# Out:
# ['9000033685']

# %%
string1="This is my mobile number 9000033685 and pan number:LITPK7695D. This is my email id edukron.bangalore@gmail.com"
re.findall(r"[a-z.]+@[a-z]{5}.[a-z]{3}",string1)
# Out:
# ['edukron.bangalore@gmail.com']

# %%
text7="for any queires pls contact on edukron_123@gmail.com"
re.findall(r"[a-z0-9._]+[a-z0-9._]+?@[a-z]{5}.[a-z]{3}",text7)
# Out:
# ['edukron_123@gmail.com']

# %%
re.findall("[a-z]$@gmail.com",string1)
# Out:
# []

# %%
 The amount was transferred from XYZ Pvt Ltd (GSTIN: 27AAACX1234B1Z9), as part of her consultancy payment. Her PAN number is APLPV2345C.
Anjali made an online purchase worth ₹8,499 on Myntra (Order ID: MYN/ORD/20250403/1147) and paid ₹2,300 for utilities through Google Pay
(Txn ID: GPay2025040312345). For inquiries, she can be contacted at +91-9988776655 or emailed at anjali.verma84@gmail.com.
Her office contact number is 080-23456789. The company also sent an invoice (Invoice No: INV/2025/XYZ-004) dated 03/04/2025.
She logged into the company portal using her ID: EMP-2025-0098."text7 = "On 04/04/2025, Ms. Anjali Verma received a credit of ₹1,20,000 in her HDFC account (A/C No: 50100233456789) via NEFT (UTR No: HDFCNEFT0425TXN00123).
