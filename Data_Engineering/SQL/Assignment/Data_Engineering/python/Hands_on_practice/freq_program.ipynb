# %%
S="Interview"
freq={}
for i in S:
  freq[i]=freq.get(i,0)+1
print(freq)
# Out:
# {'I': 1, 'n': 1, 't': 1, 'e': 2, 'r': 1, 'v': 1, 'i': 1, 'w': 1}

# %%
s="data science is data driven are data science is fun"
freq={}
words=s.split()
#print(words)
for word in words:
  freq[word]=freq.get(word,0)+1
print(freq)
# Out:
# {'data': 3, 'science': 2, 'is': 2, 'driven': 1, 'are': 1, 'fun': 1}

# %%
input=[1,2,2,3,3,4,4,4,5]
freq={}
for i in input:
  freq[i]=freq.get(i,0)+1
print(freq)
# Out:
# {1: 1, 2: 2, 3: 2, 4: 3, 5: 1}
