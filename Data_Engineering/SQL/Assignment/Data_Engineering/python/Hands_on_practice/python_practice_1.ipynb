# %%
#print numbers from 1 to 3
for i in range(1,6):
  print(i)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
#print each letter in a string
for char in "Hello":
  print(char)
# Out:
# H
# e
# l
# l
# o

# %%
#sum of numbers in a string
numbers=[1,2,3,4,5,11,12,13,14,15]
sum=0
for num in numbers:
  sum+=num
print(f"The sum of numbers is {sum}")
# Out:
# The sum of numbers is 80

# %%
#print even numbers from 1 to 10
for i in range(1,11):
  if i%2==0:
    print(i)
# Out:
# 2
# 4
# 6
# 8
# 10

# %%
#print odd numbers from 1 to 10
for i in range(1,11):
  if i%2!=0:
    print(i)
# Out:
# 1
# 3
# 5
# 7
# 9

# %%
#multiplication table of 3
n=3
for i in range(1,11):
  result=n*i
  print(f"{n} X {i} = {result}")
# Out:
# 3 X 1 = 3
# 3 X 2 = 6
# 3 X 3 = 9
# 3 X 4 = 12
# 3 X 5 = 15
# 3 X 6 = 18
# 3 X 7 = 21
# 3 X 8 = 24
# 3 X 9 = 27
# 3 X 10 = 30

# %%
fruits=["Apple", "Banana", "Cherry"]
for fruit in fruits:
  print(fruit)
# Out:
# Apple
# Banana
# Cherry

# %%
#square of numbers
n=int(input("Enter n value:"))
for i in range(n):
  print(i**2)
# Out:
# Enter n value:4
# 0
# 1
# 4
# 9

# %%
for i in range(6):
    print("For Loop 7 Square of", i, "is", i ** 2)
# Out:
# For Loop 7 Square of 0 is 0
# For Loop 7 Square of 1 is 1
# For Loop 7 Square of 2 is 4
# For Loop 7 Square of 3 is 9
# For Loop 7 Square of 4 is 16
# For Loop 7 Square of 5 is 25

# %%
student = {"name": "Alice", "age": 20}
for key in student:
    print("For Loop 8:", key, "->", student[key])
# Out:
# For Loop 8: name -> Alice
# For Loop 8: age -> 20

# %%
student={"name":"ALice","age":20}
for key in student:
  print(student[key])
# Out:
# ALice
# 20

# %%
student={"name":"ALice","age":20}
for value in student:
  print(student[value])
# Out:
# ALice
# 20

# %%
student={"name":"ALice","age":20}
for item in student:
  print(student[item])
# Out:
# ALice
# 20

# %%
for i in range(3):
  for j in range(2):
    print(i,j)
# Out:
# 0 0
# 0 1
# 1 0
# 1 1
# 2 0
# 2 1

# %%
for i in range(3):
    for j in range(2):
        print("For Loop 9 Pair:", i, j)
# Out:
# For Loop 9 Pair: 0 0
# For Loop 9 Pair: 0 1
# For Loop 9 Pair: 1 0
# For Loop 9 Pair: 1 1
# For Loop 9 Pair: 2 0
# For Loop 9 Pair: 2 1

# %%
#loop over a set
colours={"red", "green", "blue"}
for colour in colours:
  print(colour)
# Out:
# green
# blue
# red

# %%
#loop with break
for i in range(5):
  if i==3:
    break
  print(i)
# Out:
# 0
# 1
# 2

# %%
#loop with continue
for i in range(5):
  if i==2:
    continue
  print(i)
# Out:
# 0
# 1
# 3
# 4

# %%
#reverse a string
string="Hello"
#if string==string[::-1]:
print(string[::-1])
# Out:
# olleH

# %%
names=["A", "B", "C"]
scores=[90,80,70]
for name, score in zip(names, scores):
  print(name, score)
# Out:
# A 90
# B 80
# C 70

# %%
matrix = [[1, 2], [3, 4]]
for row in matrix:
    for value in row:
        print("For Loop 15 Matrix Value:", value)
# Out:
# For Loop 15 Matrix Value: 1
# For Loop 15 Matrix Value: 2
# For Loop 15 Matrix Value: 3
# For Loop 15 Matrix Value: 4

# %%
matrix=[[1,2],[3,4]]
for row in matrix:
  for value in row:
    print("Matrix value is:", value)
# Out:
# Matrix value is: 1
# Matrix value is: 2
# Matrix value is: 3
# Matrix value is: 4

# %%
#list comprehension
squares=[x**2 for x in range(5)]
print(squares)
# Out:
# [0, 1, 4, 9, 16]

# %%
#loop with else
for i in range(3):
  print(i)
else:
  print("None")
# Out:
# 0
# 1
# 2
# None

# %%
for char in "education":
  if char in "aeiou":
    print(char)
# Out:
# e
# u
# a
# i
# o

# %%
for char in "education":
    if char in 'aeiou':
        print("For Loop 18 Vowel:", char)
# Out:
# For Loop 18 Vowel: e
# For Loop 18 Vowel: u
# For Loop 18 Vowel: a
# For Loop 18 Vowel: i
# For Loop 18 Vowel: o

# %%
for char in "AB":
    print("For Loop 19:", char, "->", ord(char))
# Out:
# For Loop 19: A -> 65
# For Loop 19: B -> 66

# %%
for ch in "ABcdef":
  print(ch, ord(ch))
# Out:
# A 65
# B 66
# c 99
# d 100
# e 101
# f 102

# %%
for i in range(5,0,-1):
  print(i)
# Out:
# 5
# 4
# 3
# 2
# 1
